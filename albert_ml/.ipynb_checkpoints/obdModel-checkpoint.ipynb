# %%
import pandas as pd
import numpy as np
import matplotlib as plt
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import train_test_split
from sklearn.feature_selection import SelectKBest, chi2
from sklearn import preprocessing
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-1-9e2b2e15109c> in <module>
# ----> 1 import pandas as pd
#       2 import numpy as np
#       3 import matplotlib as plt
#       4 from sklearn.ensemble import RandomForestClassifier
#       5 from sklearn.model_selection import train_test_split
#
# ModuleNotFoundError: No module named 'pandas'

# %%
obdData1="opel_corsa_01_clean.csv"
obdData2="peugeot_207_01_clean.csv"
df1=pd.read_csv(obdData1,sep = ';')
df2=pd.read_csv(obdData2,sep = ';')
frames=[df1,df2]
totalDf=pd.concat(frames)
cleanData=totalDf.dropna()
cleanData.head(20)
#list(df1.columns)
#df1.describe()
# Out:
#       VehicleSpeedInstantaneous  VehicleSpeedAverage  \
# 59          -2.299988                  25.670519            13.223501
# 60          -2.099976                  24.094259            13.638919
# 61          -1.500000                  22.743179            14.031043
# 62           0.100037                  22.292820            14.171073
# 63           0.099976                  23.643900            14.328954
# 64           0.100037                  24.769798            14.741783
# 65           0.300049                  25.445337            15.139601
# 66           0.299988                  26.796419            15.571196
# 67           0.200012                  28.147499            16.014050
# 68           0.600037                  29.723761            16.486928
# 69           0.500000                  31.525200            16.986077
# 70           0.400024                  34.227360            17.556533
# 71          -0.600037                  35.803623            18.145754
# 72          -0.899963                  37.154701            18.764999
# 73          -1.200012                  39.406498            19.421774
# 74          -0.900024                  40.307220            20.093561
# 75          -0.700012                  40.307220            20.765348
# 76          -0.100037                  40.307220            21.410864
# 77           0.199951                  39.181320            22.052627
# 78           0.400024                  40.307220            22.716908
#
#     VehicleSpeedVariance  VehicleSpeedVariation  LongitudinalAcceleration  \
# 59            121.592690              -2.476980                    0.3555
# 60            120.422571              -1.576260                    0.4492
# 61            118.456769              -1.351080                    0.4258
# 62            117.571308              -0.450359                    0.4140
# 63            117.074149               1.351080                    0.3945
# 64            115.268498               1.125898                    0.2187
# 65            114.111541               0.675539                    0.1719
# 66            112.788815               1.351082                    0.1523
# 67            111.950475               1.351080                    0.0508
# 68            111.264656               1.576262                    0.0391
# 69            111.076056               1.801439                    0.1094
# 70            110.893171               2.702160                    0.1328
# 71            111.223751               1.576263                    0.0312
# 72            111.377375               1.351078                    0.0391
# 73            112.192036               2.251797                    0.1094
# 74            112.733031               0.900722                    0.1172
# 75            112.356131               0.000000                    0.1406
# 76            112.163965               0.000000                    0.2539
# 77            109.810132              -1.125900                    0.1055
# 78            107.099895               1.125900                   -0.0156
#
#     EngineLoad  EngineCoolantTemperature  ManifoldAbsolutePressure  EngineRPM  \
# 59    4.705883                      68.0                     106.0     1796.0
# 60   10.588236                      68.0                     103.0     1689.0
# 61   27.450981                      68.0                     103.0     1599.0
# 62   24.313726                      69.0                     104.0     1620.0
# 63   20.000000                      69.0                     104.0     1708.0
# 64   23.529411                      69.0                     104.0     1787.0
# 65   23.137255                      69.0                     105.0     1804.0
# 66   26.274509                      69.0                     108.0     1939.0
# 67   29.411766                      69.0                     113.0     2151.0
# 68   35.686275                      69.0                     119.0     2270.0
# 69   41.960785                      69.0                     133.0     2452.0
# 70   25.098040                      69.0                     130.0     2169.0
# 71   59.215687                      69.0                     117.0     1589.0
# 72   51.372551                      70.0                     124.0     1682.0
# 73   30.196079                      70.0                     117.0     1734.0
# 74   19.215687                      70.0                     106.0     1744.0
# 75   17.647058                      70.0                     104.0     1721.0
# 76    6.274510                      70.0                     102.0     1706.0
# 77   32.549019                      70.0                     104.0     1740.0
# 78   47.843140                      70.0                     117.0     1814.0
#
#     MassAirFlow  IntakeAirTemperature  VerticalAcceleration  \
# 59    15.810000                  24.0               -0.1133
# 60    14.650000                  22.0               -0.1289
# 61    11.850000                  21.0               -0.1328
# 62    12.210000                  20.0               -0.0859
# 63    11.910000                  21.0               -0.0664
# 64    11.370000                  20.0               -0.0703
# 65    11.730000                  21.0               -0.0820
# 66    13.830000                  21.0               -0.1289
# 67    16.389999                  22.0               -0.2031
# 68    17.969999                  22.0               -0.1406
# 69    22.500000                  23.0               -0.0469
# 70    26.230000                  23.0               -0.0820
# 71    20.350000                  22.0               -0.0664
# 72    19.879999                  22.0               -0.0625
# 73    20.740000                  22.0               -0.0742
# 74    12.460000                  20.0               -0.1367
# 75    11.200000                  19.0               -0.0937
# 76    11.100000                  19.0                0.0156
# 77    12.030000                  19.0                0.0625
# 78    23.280001                  20.0                0.1953
#
#     FuelConsumptionAverage      roadSurface                 traffic  \
# 59               19.497335  SmoothCondition  LowCongestionCondition
# 60               19.515722  SmoothCondition  LowCongestionCondition
# 61               19.441765  SmoothCondition  LowCongestionCondition
# 62               19.388769  SmoothCondition  LowCongestionCondition
# 63               19.301638  SmoothCondition  LowCongestionCondition
# 64               19.169611  SmoothCondition  LowCongestionCondition
# 65               19.040903  SmoothCondition  LowCongestionCondition
# 66               18.986486  SmoothCondition  LowCongestionCondition
# 67               18.979977  SmoothCondition  LowCongestionCondition
# 68               18.997944  SmoothCondition  LowCongestionCondition
# 69               19.074064  SmoothCondition  LowCongestionCondition
# 70               19.168253  SmoothCondition  LowCongestionCondition
# 71               19.158426  SmoothCondition  LowCongestionCondition
# 72               19.128201  SmoothCondition  LowCongestionCondition
# 73               19.084410  SmoothCondition  LowCongestionCondition
# 74               18.754362  SmoothCondition  LowCongestionCondition
# 75               18.374681  SmoothCondition  LowCongestionCondition
# 76               18.017460  SmoothCondition  LowCongestionCondition
# 77               17.751122  SmoothCondition  LowCongestionCondition
# 78               17.700039  SmoothCondition  LowCongestionCondition
#
#      drivingStyle
# 59  EvenPaceStyle
# 60  EvenPaceStyle
# 61  EvenPaceStyle
# 62  EvenPaceStyle
# 63  EvenPaceStyle
# 64  EvenPaceStyle
# 65  EvenPaceStyle
# 66  EvenPaceStyle
# 67  EvenPaceStyle
# 68  EvenPaceStyle
# 69  EvenPaceStyle
# 70  EvenPaceStyle
# 71  EvenPaceStyle
# 72  EvenPaceStyle
# 73  EvenPaceStyle
# 74  EvenPaceStyle
# 75  EvenPaceStyle
# 76  EvenPaceStyle
# 77  EvenPaceStyle
# 78  EvenPaceStyle

# %%
#totalDf.shape

cleanData.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 15230 entries, 59 to 8613
# Data columns (total 17 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0             15230 non-null  float64
#  1   VehicleSpeedInstantaneous  15230 non-null  float64
#  2   VehicleSpeedAverage        15230 non-null  float64
#  3   VehicleSpeedVariance       15230 non-null  float64
#  4   VehicleSpeedVariation      15230 non-null  float64
#  5   LongitudinalAcceleration   15230 non-null  float64
#  6   EngineLoad                 15230 non-null  float64
#  7   EngineCoolantTemperature   15230 non-null  float64
#  8   ManifoldAbsolutePressure   15230 non-null  float64
#  9   EngineRPM                  15230 non-null  float64
#  10  MassAirFlow                15230 non-null  float64
#  11  IntakeAirTemperature       15230 non-null  float64
#  12  VerticalAcceleration       15230 non-null  float64
#  13  FuelConsumptionAverage     15230 non-null  float64
#  14  roadSurface                15230 non-null  object
#  15  traffic                    15230 non-null  object
#  16  drivingStyle               15230 non-null  object
# dtypes: float64(14), object(3)
# memory usage: 2.1+ MB

# %%
#lb = preprocessing.LabelBinarizer()
#style=cleanData['drivingStyle'].copy()
#cleanData['drivingStyle'] = lb.fit_transform(style)
cleanup_nums = {"drivingStyle": {"EvenPaceStyle": 0, "AggressiveStyle": 1 }}
cleanData = cleanData.replace(cleanup_nums)
#cleanData["drivingCode"] = np.where(cleanData["drivingStyle"].str.contains("EvenPaceStyle"), 1, 0)
#pd.to_numeric(cleanData['drivingCode'].values)
#cleanData.head()
cleanData['drivingStyle'].value_counts()
# Out:
# 0    13460
# 1     1770
# Name: drivingStyle, dtype: int64

# %%
#tempCleanData=cleanData[:,:-3]
#tempCleanData.info()
#tempCleanData['drivingStyle']=cleanData['drivingStyle']

# %%
dataset=cleanData.values
#tempData=cleanData[["VehicleSpeedInstantaneous","VehicleSpeedAverage"]]
X=dataset[:,:-3]
X.shape
#X=tempData.copy().values
#X=pd.to_numeric(dataset[:,:-3])
y=pd.to_numeric(dataset[:,-1])
#cleanData.values[:,-1]
# Out:
# Error: Jupyter cannot be started. Error attempting to locate jupyter: Data Science libraries notebook and jupyter are not installed in interpreter Python 3.8.1 64-bit.
# at A.startServer (/Users/leftee/.vscode/extensions/ms-python.python-2020.2.64397/out/client/extension.js:1:786058)
# at A.ensureServerAndNotebookImpl (/Users/leftee/.vscode/extensions/ms-python.python-2020.2.64397/out/client/extension.js:1:785513)
# at A.ensureServerAndNotebook (/Users/leftee/.vscode/extensions/ms-python.python-2020.2.64397/out/client/extension.js:1:785314)
# at A.submitCode (/Users/leftee/.vscode/extensions/ms-python.python-2020.2.64397/out/client/extension.js:1:782266)
# at A.reexecuteCell (/Users/leftee/.vscode/extensions/ms-python.python-2020.2.64397/out/client/extension.js:75:879318)

# %%
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.2)
print("train",X_train.shape,y_train.shape)
print("test",X_test.shape,y_test.shape)
# Out:
# train (12184, 14) (12184,)
# test (3046, 14) (3046,)

# %%
#fs=SelectKBest(score_func=chi2, k='all')
#fs.fit(X_train,y_train)

# %%
from sklearn import preprocessing
from sklearn.model_selection import cross_val_score, cross_val_predict
from sklearn.metrics import accuracy_score, classification_report
from sklearn.metrics import confusion_matrix, roc_auc_score
def print_score(clf, X_train, X_test, y_train, y_test, train=True):
    '''
    v0.1 Follow the scikit learn library format in terms of input
    print the accuracy score, classification report and confusion matrix of classifier
    '''
    lb = preprocessing.LabelBinarizer()
    lb.fit(y_train)
    if train:
        '''
        training performance
        '''
        res = clf.predict(X_train)
        print("Train Result:\n")
        print("accuracy score: {0:.4f}\n".format(accuracy_score(y_train, 
                                                                res)))
        print("Classification Report: \n {}\n".format(classification_report(y_train, 
                                                                            res)))
        print("Confusion Matrix: \n {}\n".format(confusion_matrix(y_train, 
                                                                  res)))
        print("ROC AUC: {0:.4f}\n".format(roc_auc_score(lb.transform(y_train), 
                                                      lb.transform(res))))

        res = cross_val_score(clf, X_train, y_train, cv=10, scoring='accuracy')
        print("Average Accuracy: \t {0:.4f}".format(np.mean(res)))
        print("Accuracy SD: \t\t {0:.4f}".format(np.std(res)))
        
    elif train==False:
        '''
        test performance
        '''
        res_test = clf.predict(X_test)
        print("Test Result:\n")        
        print("accuracy score: {0:.4f}\n".format(accuracy_score(y_test, 
                                                                res_test)))
        print("Classification Report: \n {}\n".format(classification_report(y_test, 
                                                                            res_test)))
        print("Confusion Matrix: \n {}\n".format(confusion_matrix(y_test, 
                                                                  res_test)))   
        print("ROC AUC: {0:.4f}\n".format(roc_auc_score(lb.transform(y_test), 
                                                      lb.transform(res_test))))

# %%
rf_clf = RandomForestClassifier(random_state=42, n_estimators=100)

# %%
#tester=pd.to_numeric(y_train)
#tester
#y_train=tester

# %%
rf_clf.fit(X_train, y_train)
# Out:
# RandomForestClassifier(random_state=42)

# %%
print_score(rf_clf, X_train, X_test, y_train, y_test, train=True)
print("\n******************************\n")
print_score(rf_clf, X_train, X_test, y_train, y_test, train=False)
# Out:
# Train Result:
#
# accuracy score: 1.0000
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00     10779
#            1       1.00      1.00      1.00      1405
#
#     accuracy                           1.00     12184
#    macro avg       1.00      1.00      1.00     12184
# weighted avg       1.00      1.00      1.00     12184
#
#
# Confusion Matrix:
#  [[10779     0]
#  [    0  1405]]
#
# ROC AUC: 1.0000
#
# Average Accuracy: 	 0.9446
# Accuracy SD: 		 0.0065
#
# ******************************
#
# Test Result:
#
# accuracy score: 0.9508
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.95      0.99      0.97      2681
#            1       0.92      0.64      0.76       365
#
#     accuracy                           0.95      3046
#    macro avg       0.94      0.82      0.87      3046
# weighted avg       0.95      0.95      0.95      3046
#
#
# Confusion Matrix:
#  [[2661   20]
#  [ 130  235]]
#
# ROC AUC: 0.8182
